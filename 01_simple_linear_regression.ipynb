# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevan-Neupane/Machine-Learning-Algorithms/blob/main/01_simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Salary_Data.csv")
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X= dataset.iloc[:,:-1].values
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y=dataset.iloc[:,-1].values
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0);
X_train,X_test
# Out:
# (array([[ 2.9],
#         [ 5.1],
#         [ 3.2],
#         [ 4.5],
#         [ 8.2],
#         [ 6.8],
#         [ 1.3],
#         [10.5],
#         [ 3. ],
#         [ 2.2],
#         [ 5.9],
#         [ 6. ],
#         [ 3.7],
#         [ 3.2],
#         [ 9. ],
#         [ 2. ],
#         [ 1.1],
#         [ 7.1],
#         [ 4.9],
#         [ 4. ]]),
#  array([[ 1.5],
#         [10.3],
#         [ 4.1],
#         [ 3.9],
#         [ 9.5],
#         [ 8.7],
#         [ 9.6],
#         [ 4. ],
#         [ 5.3],
#         [ 7.9]]))

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression();

regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test);
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
y_test
# Out:
# array([ 37731., 122391.,  57081.,  63218., 116969., 109431., 112635.,
#         55794.,  83088., 101302.])

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train,y_train,color="blue",label="Actual (Training Data)")
plt.plot(X_test,y_pred,color="red",label="Regression Line")

# %% [markdown]
# ## Evaluation of Model

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 21026037.329511296

# %%
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 21026037.329511296
# R² Score: 0.9749154407708353

# %%
# Example prediction
new_experience = [[3.0]]  # 3 years of experience
predicted_salary = regressor.predict(new_experience)
print("Predicted Salary for 3 years of experience:", predicted_salary[0])
# Out:
# Predicted Salary for 3 years of experience: 54854.0195733983

# %%
# Install necessary libraries
# !pip install fastapi uvicorn joblib
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !mv ngrok /usr/local/bin

# Authenticate ngrok (replace YOUR_AUTH_TOKEN with your actual token)
# !ngrok authtoken 2ovgGDemz2CZjh1BJV88lTZ8Kpd_5NUZdGjtugnC1VhHyUL7h
# Out:
# ...
# --2024-11-26 02:55:13--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 13.248.244.96, 35.71.179.82, 75.2.60.68, ...
# Connecting to bin.equinox.io (bin.equinox.io)|13.248.244.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.2’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  36.8MB/s    in 0.4s
#
# 2024-11-26 02:55:14 (36.8 MB/s) - ‘ngrok-stable-linux-amd64.zip.2’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
import subprocess

# Save your FastAPI app code into a file
with open("main.py", "w") as f:
    f.write('''
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import joblib
import numpy as np

# Load the saved model
model = joblib.load("linear_regression_model.pkl")

# Initialize FastAPI app
app = FastAPI()

# Request body model
class PredictionRequest(BaseModel):
    YearsExperience: float

@app.post("/predict/")
async def predict(data: PredictionRequest):
    # Extract input value
    years_experience = data.YearsExperience

    if years_experience is None:
        raise HTTPException(status_code=400, detail="YearsExperience is required")

    # Perform prediction
    prediction = model.predict(np.array([[years_experience]]))[0]

    # Return response
    return {"YearsExperience": years_experience, "PredictedSalary": prediction}
    ''')

# Run the FastAPI app using uvicorn
subprocess.Popen(["uvicorn", "main:app", "--host", "0.0.0.0", "--port", "8000"])
# Out:
# <Popen: returncode: None args: ['uvicorn', 'main:app', '--host', '0.0.0.0', ...>

# %%
# Start ngrok in the background to expose the FastAPI app
get_ipython().system_raw("ngrok http 8000 &")


import requests

# Wait for ngrok to fully start and then fetch the tunnel URL
import time
time.sleep(2)  # Allow ngrok time to initialize

# Fetch the public URL for the API
ngrok_url = None
try:
    # Get the public URL from ngrok's API endpoint
    response = requests.get("http://localhost:4040/api/tunnels")
    if response.status_code == 200:
        tunnels = response.json()['tunnels']
        ngrok_url = tunnels[0]['public_url']
        print(f"Public URL: {ngrok_url}")
    else:
        print("Error fetching ngrok URL")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: HTTPConnectionPool(host='localhost', port=4040): Max retries exceeded with url: /api/tunnels (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7919447a20e0>: Failed to establish a new connection: [Errno 111] Connection refused'))
